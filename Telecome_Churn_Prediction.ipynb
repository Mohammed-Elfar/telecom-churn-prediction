# %%
import pandas as pd 
import numpy as np 
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Combining 2 df to do univariate analysis And cleaning

# %%
df1 = pd.read_csv('/Users/mohammedmahmood/Desktop/Data projects/Data science/Telecome_Churn_Prediction /data/churn-bigml-20.csv')
df2 = pd.read_csv('/Users/mohammedmahmood/Desktop/Data projects/Data science/Telecome_Churn_Prediction /data/churn-bigml-80.csv')

df = pd.concat([df1, df2], ignore_index=True)
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
# Add underscores to column names
df.columns = df.columns.str.replace(' ', '_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account_length          3333 non-null   int64
#  2   Area_code               3333 non-null   int64
#  3   International_plan      3333 non-null   object
#  4   Voice_mail_plan         3333 non-null   object
#  5   Number_vmail_messages   3333 non-null   int64
#  6   Total_day_minutes       3333 non-null   float64
#  7   Total_day_calls         3333 non-null   int64
#  8   Total_day_charge        3333 non-null   float64
#  9   Total_eve_minutes       3333 non-null   float64
#  10  Total_eve_calls         3333 non-null   int64
#  11  Total_eve_charge        3333 non-null   float64
#  12  Total_night_minutes     3333 non-null   float64
#  13  Total_night_calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account_length    Area_code  Number_vmail_messages  Total_day_minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total_day_calls  Total_day_charge  Total_eve_minutes  Total_eve_calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ## Check Nulls

# %%
# Nulls
df.isna().sum()
# Out:
# State                     0
# Account_length            0
# Area_code                 0
# International_plan        0
# Voice_mail_plan           0
# Number_vmail_messages     0
# Total_day_minutes         0
# Total_day_calls           0
# Total_day_charge          0
# Total_eve_minutes         0
# Total_eve_calls           0
# Total_eve_charge          0
# Total_night_minutes       0
# Total_night_calls         0
# Total_night_charge        0
# Total_intl_minutes        0
# Total_intl_calls          0
# Total_intl_charge         0
# Customer_service_calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ##  Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Univariate analysis
#
# ### **In this step i will go through each column and fix problems in and do Eda for features to understand**

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ## State

# %%
df.State.unique()
# Out:
# array(['LA', 'IN', 'NY', 'SC', 'HI', 'AK', 'MI', 'ID', 'VA', 'WI', 'MN',
#        'VT', 'MT', 'MA', 'KY', 'CO', 'AZ', 'CA', 'WA', 'NE', 'OH', 'MO',
#        'AL', 'NH', 'NM', 'OR', 'TX', 'MS', 'WY', 'FL', 'KS', 'NC', 'SD',
#        'OK', 'CT', 'RI', 'DE', 'UT', 'NV', 'DC', 'ME', 'IL', 'NJ', 'MD',
#        'WV', 'PA', 'ND', 'AR', 'TN', 'IA', 'GA'], dtype=object)

# %%
df.State.value_counts()
# Out:
# State
# WV    106
# MN     84
# NY     83
# AL     80
# OR     78
# OH     78
# WI     78
# VA     77
# WY     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# KS     70
# MD     70
# MT     68
# NJ     68
# NC     68
# NV     66
# WA     66
# CO     66
# MA     65
# MS     65
# RI     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ND     62
# ME     62
# OK     61
# NE     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64

# %% [markdown]
# ## Account_length

# %%
df.Account_length.value_counts()
# Out:
# Account_length
# 105    43
# 87     42
# 93     40
# 101    40
# 90     39
#        ..
# 232     1
# 191     1
# 5       1
# 200     1
# 221     1
# Name: count, Length: 212, dtype: int64

# %%
df.Account_length.describe()
# Out:
# count    3333.000000
# mean      101.064806
# std        39.822106
# min         1.000000
# 25%        74.000000
# 50%       101.000000
# 75%       127.000000
# max       243.000000
# Name: Account_length, dtype: float64

# %%
px.histogram(df , x= "Account_length" )

# %% [markdown]
# ## Area_code

# %%
df.Area_code.unique()
# Out:
# array([408, 415, 510])

# %%
df.Area_code.value_counts()
# Out:
# Area_code
# 415    1655
# 510     840
# 408     838
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ## International_plan

# %%
df.International_plan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.International_plan.value_counts()
# Out:
# International_plan
# No     3010
# Yes     323
# Name: count, dtype: int64

# %% [markdown]
# ## Voice_mail_plan

# %%
df.Voice_mail_plan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## Number_vmail_messages

# %%
df.Number_vmail_messages.unique()
# Out:
# array([ 0, 30, 33, 29, 32, 27, 22, 23, 41, 48, 24, 34, 37, 35, 21, 26, 16,
#        20, 18, 31, 14, 28, 39, 36, 45, 51, 38, 11, 19, 15, 25, 40, 49, 17,
#        42, 13, 46, 43, 12, 47,  8, 44,  4, 10, 50,  9])

# %%
px.histogram(df, x= "Number_vmail_messages" )

# %% [markdown]
# ## Total_day_minutes

# %%
df.Total_day_minutes.describe()
# Out:
# count    3333.000000
# mean      179.775098
# std        54.467389
# min         0.000000
# 25%       143.700000
# 50%       179.400000
# 75%       216.400000
# max       350.800000
# Name: Total_day_minutes, dtype: float64

# %%
px.histogram(df, x= "Total_day_minutes")

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ### Total_day_calls

# %%
df.Total_day_minutes.describe()
# Out:
# count    3333.000000
# mean      179.775098
# std        54.467389
# min         0.000000
# 25%       143.700000
# 50%       179.400000
# 75%       216.400000
# max       350.800000
# Name: Total_day_minutes, dtype: float64

# %%
px.histogram(df, x= "Total_day_calls")

# %% [markdown]
# ## Total_eve_minutes

# %%
df.Total_day_minutes.describe()
# Out:
# count    3333.000000
# mean      179.775098
# std        54.467389
# min         0.000000
# 25%       143.700000
# 50%       179.400000
# 75%       216.400000
# max       350.800000
# Name: Total_day_minutes, dtype: float64

# %%
px.histogram(df, x= "Total_day_minutes")

# %% [markdown]
# ## Total_eve_calls

# %%
df.Total_eve_calls.value_counts()
# Out:
# Total_eve_calls
# 105    80
# 94     79
# 108    71
# 97     70
# 102    70
#        ..
# 49      1
# 42      1
# 164     1
# 168     1
# 170     1
# Name: count, Length: 123, dtype: int64

# %%
px.histogram(df, x= "Total_eve_calls")

# %%
px.box(df, x= "Total_eve_calls")

# %%
df.Total_eve_calls.describe()
# Out:
# count    3333.000000
# mean      100.114311
# std        19.922625
# min         0.000000
# 25%        87.000000
# 50%       100.000000
# 75%       114.000000
# max       170.000000
# Name: Total_eve_calls, dtype: float64

# %% [markdown]
# ## Total_eve_charge

# %%
df.Total_eve_charge.describe()
# Out:
# count    3333.000000
# mean       17.083540
# std         4.310668
# min         0.000000
# 25%        14.160000
# 50%        17.120000
# 75%        20.000000
# max        30.910000
# Name: Total_eve_charge, dtype: float64

# %%
px.histogram(df, x= "Total_eve_charge")

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ## Total_night_minutes

# %%
df.Total_night_minutes.describe()
# Out:
# count    3333.000000
# mean      200.872037
# std        50.573847
# min        23.200000
# 25%       167.000000
# 50%       201.200000
# 75%       235.300000
# max       395.000000
# Name: Total_night_minutes, dtype: float64

# %%
px.histogram(df, x= "Total_night_minutes")

# %% [markdown]
# ## Total_night_calls

# %%
df.Total_night_calls.describe()
# Out:
# count    3333.000000
# mean      100.107711
# std        19.568609
# min        33.000000
# 25%        87.000000
# 50%       100.000000
# 75%       113.000000
# max       175.000000
# Name: Total_night_calls, dtype: float64

# %%
px.histogram(df, x= "Total_night_calls")

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ##

# %% [markdown]
# ## Total_night_charge

# %%
df.Total_night_charge.describe()
# Out:
# count    3333.000000
# mean        9.039325
# std         2.275873
# min         1.040000
# 25%         7.520000
# 50%         9.050000
# 75%        10.590000
# max        17.770000
# Name: Total_night_charge, dtype: float64

# %%
px.histogram(df, x= "Total_night_charge")

# %% [markdown]
# ### Customer_service_calls

# %%
df.Customer_service_calls.unique()
# Out:
# array([1, 4, 2, 0, 3, 5, 6, 8, 7, 9])

# %%
df.Customer_service_calls.value_counts()
# Out:
# Customer_service_calls
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 8       2
# 9       2
# Name: count, dtype: int64

# %%
px.box(df, x = "Customer_service_calls" )

# %% [markdown]
# ## Churn

# %%
df.Churn.unique()
# Out:
# array([False,  True])

# %%
df.Churn.value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
df["Churn"] = df["Churn"].map({False :0, True :1})

# %% [markdown]
# ## Targe is imbalanced, and i will handle it

# %% [markdown]
# ## Handling outliers

# %%
from datasist.structdata import detect_outliers

# Selecting numeric columns
columns = df.select_dtypes(include=['number']).columns

for column in columns:
    outliers = detect_outliers(df, 0, [column]) 
    print(f"Number of outliers in '{column}': {len(outliers)}")
# Out:
# Number of outliers in 'Account_length': 18
# Number of outliers in 'Area_code': 0
# Number of outliers in 'Number_vmail_messages': 1
# Number of outliers in 'Total_day_minutes': 25
# Number of outliers in 'Total_day_calls': 23
# Number of outliers in 'Total_day_charge': 25
# Number of outliers in 'Total_eve_minutes': 24
# Number of outliers in 'Total_eve_calls': 20
# Number of outliers in 'Total_eve_charge': 24
# Number of outliers in 'Total_night_minutes': 30
# Number of outliers in 'Total_night_calls': 22
# Number of outliers in 'Total_night_charge': 30
# Number of outliers in 'Total_intl_minutes': 46
# Number of outliers in 'Total_intl_calls': 78
# Number of outliers in 'Total_intl_charge': 49
# Number of outliers in 'Customer_service_calls': 267
# Number of outliers in 'Churn': 483

# %%
# outlier_columns = ['Total_intl_calls', 'Total_intl_charge', 'Total_intl_minutes', 'Total_night_charge', "Total_night_minutes"]

# outliers = detect_outliers(df, 0, outlier_columns) 

# df.drop(outliers, inplace = True, axis= 0)

# %% [markdown]
# # Feature engineering

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ## Create derived columns to enhance model learning.

# %% [markdown]
# ## total_calls

# %%
df['total_calls'] = (df['Total_day_calls'] + df['Total_eve_calls'] + df['Total_night_calls'] + df['Total_intl_calls'])

# %%
df.total_calls.describe()
# Out:
# count    3333.000000
# mean      305.137114
# std        34.448164
# min       191.000000
# 25%       282.000000
# 50%       305.000000
# 75%       328.000000
# max       416.000000
# Name: total_calls, dtype: float64

# %% [markdown]
# ## total_charge

# %%
df['total_charge'] = (df['Total_day_charge'] +  df['Total_eve_charge'] +  df['Total_night_charge'] )

# %% [markdown]
# ## tota_minutes

# %%
df['tota_minutes'] = df['Total_day_minutes'] + df['Total_eve_minutes'] + df['Total_night_minutes']

# %%
df
# Out:
#      State  Account_length  Area_code International_plan Voice_mail_plan  \
# 0       LA             117        408                 No              No
# 1       IN              65        415                 No              No
# 2       NY             161        415                 No              No
# 3       SC             111        415                 No              No
# 4       HI              49        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3328    SC              79        415                 No              No
# 3329    AZ             192        415                 No             Yes
# 3330    WV              68        415                 No              No
# 3331    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number_vmail_messages  Total_day_minutes  Total_day_calls  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account_length', 'Area_code', 'International_plan',
#        'Voice_mail_plan', 'Number_vmail_messages', 'Total_day_minutes',
#        'Total_day_calls', 'Total_day_charge', 'Total_eve_minutes',
#        'Total_eve_calls', 'Total_eve_charge', 'Total_night_minutes',
#        'Total_night_calls', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn', 'total_calls', 'total_charge', 'tota_minutes'],
#       dtype='object')

# %% [markdown]
# # Feature Importance

# %% [markdown]
# ## 1-corrolation

# %%
num_cols = df.select_dtypes(include='number').columns

# Compute correlation with 'Churn'
correlations = df[num_cols].corr()['Churn'].sort_values(ascending=False)

correlations
# Out:
# Churn                     1.000000
# total_charge              0.226962
# Customer_service_calls    0.208750
# Total_day_minutes         0.205151
# Total_day_charge          0.205151
# tota_minutes              0.196457
# Total_eve_minutes         0.092796
# Total_eve_charge          0.092786
# Total_intl_charge         0.068259
# Total_intl_minutes        0.068239
# Total_night_charge        0.035496
# Total_night_minutes       0.035493
# Total_day_calls           0.018459
# Account_length            0.016541
# total_calls               0.015807
# Total_eve_calls           0.009233
# Area_code                 0.006174
# Total_night_calls         0.006141
# Total_intl_calls         -0.052844
# Number_vmail_messages    -0.089728
# Name: Churn, dtype: float64

# %%
import plotly.express as px

# Step 1: Select only numerical columns from the DataFrame
num_df = df.select_dtypes(include="number")

# Step 2: Compute the correlation matrix
corr_matrix = num_df.corr()

# Step 3: Create the heatmap
fig = px.imshow(corr_matrix, 
                text_auto=True, 
                aspect="auto",  
                title="Correlation Heatmap",
                width=1950,
                height=1100)

# Step 4: Show the figure
fig.show()

# %%
df_Cat = df.select_dtypes(include="object")

# %%
for col in df_Cat.columns :
    print(f"Column {col} has {df_Cat[col].nunique()} values")
# Out:
# Column State has 51 values
# Column International_plan has 2 values
# Column Voice_mail_plan has 2 values

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Account_length', 'Area_code', 'Number_vmail_messages',
#        'Total_day_minutes', 'Total_day_calls', 'Total_day_charge',
#        'Total_eve_minutes', 'Total_eve_calls', 'Total_eve_charge',
#        'Total_night_minutes', 'Total_night_calls', 'Total_night_charge',
#        'Total_intl_minutes', 'Total_intl_calls', 'Total_intl_charge',
#        'Customer_service_calls', 'Churn', 'total_calls', 'total_charge',
#        'tota_minutes'],
#       dtype='object')

# %% [markdown]
# ###  encoding cat columns to do feature importance using ExtraTreesClassifier

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import ExtraTreesClassifier

cat_cols = [
    'State', 'International_plan', "Voice_mail_plan"
]

num_cols = ["Account_length", 'Area_code', 'Number_vmail_messages',
       'Total_day_minutes', 'Total_day_calls', 'Total_day_charge',
       'Total_eve_minutes', 'Total_eve_calls', 'Total_eve_charge',
       'Total_night_minutes', 'Total_night_calls', 'Total_night_charge',
       'Total_intl_minutes', 'Total_intl_calls', 'Total_intl_charge',
       'Customer_service_calls', 'total_calls', 'total_charge',
       'tota_minutes']

df_encoded = df.copy()
for col in cat_cols:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))


X = df_encoded[cat_cols + num_cols]
y = df_encoded['Churn']

# %% [markdown]
# ## 2-Model-Based Feature Importance (ExtraTreesClassifier)

# %%
# Fit ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators=100, random_state=42)
model.fit(X, y)

# Get feature importances
importances = pd.Series(model.feature_importances_, index=X.columns)
importances_sorted = importances.sort_values(ascending=False)

# Show  features
importances_sorted
# Out:
# Customer_service_calls    0.114755
# total_charge              0.114155
# Total_day_minutes         0.085047
# tota_minutes              0.078164
# Total_day_charge          0.077595
# International_plan        0.070771
# Total_intl_calls          0.041393
# Total_intl_minutes        0.039068
# Total_intl_charge         0.035785
# Total_eve_charge          0.034924
# Total_eve_minutes         0.033117
# Total_day_calls           0.027853
# Total_night_charge        0.027400
# Total_night_minutes       0.027400
# Total_night_calls         0.026563
# Voice_mail_plan           0.025627
# Account_length            0.025464
# total_calls               0.025166
# Total_eve_calls           0.025020
# State                     0.024695
# Number_vmail_messages     0.022086
# Area_code                 0.017951
# dtype: float64

# %%
# # deleting column that has low corrolation 
df.drop(["Account_length", "Total_day_calls", "total_calls", "Total_night_calls", "Total_eve_calls", "State", "Area_code", "Number_vmail_messages" ], axis= 1, inplace= True )

# %%
from datasist.structdata import detect_outliers

# Selecting numeric columns
columns = df.select_dtypes(include=['number']).columns

for column in columns:
    outliers = detect_outliers(df, 0, [column]) 
    print(f"Number of outliers in '{column}': {len(outliers)}")
# Out:
# Number of outliers in 'Total_day_minutes': 25
# Number of outliers in 'Total_day_charge': 25
# Number of outliers in 'Total_eve_minutes': 24
# Number of outliers in 'Total_eve_charge': 24
# Number of outliers in 'Total_night_minutes': 30
# Number of outliers in 'Total_night_charge': 30
# Number of outliers in 'Total_intl_minutes': 46
# Number of outliers in 'Total_intl_calls': 78
# Number of outliers in 'Total_intl_charge': 49
# Number of outliers in 'Customer_service_calls': 267
# Number of outliers in 'Churn': 483
# Number of outliers in 'total_charge': 27
# Number of outliers in 'tota_minutes': 16

# %%
df.isna()
# Out:
#       International_plan  Voice_mail_plan  Total_day_minutes  \
# 0                  False            False              False
# 1                  False            False              False
# 2                  False            False              False
# 3                  False            False              False
# 4                  False            False              False
# ...                  ...              ...                ...
# 3328               False            False              False
# 3329               False            False              False
# 3330               False            False              False
# 3331               False            False              False
# 3332               False            False              False
#
#       Total_day_charge  Total_eve_minutes  Total_eve_charge  \
# 0                False              False             False
# 1                False              False             False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# International_plan        0
# Voice_mail_plan           0
# Total_day_minutes         0
# Total_day_charge          0
# Total_eve_minutes         0
# Total_eve_charge          0
# Total_night_minutes       0
# Total_night_charge        0
# Total_intl_minutes        0
# Total_intl_calls          0
# Total_intl_charge         0
# Customer_service_calls    0
# Churn                     0
# total_charge              0
# tota_minutes              0
# dtype: int64

# %%
cat_columns = df.select_dtypes(include=['object', "bool" ]).columns  

# Print unique values for each categorical column
for col in cat_columns:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 50)
# Out:
# Unique values in 'International_plan':
# ['No' 'Yes']
# --------------------------------------------------
# Unique values in 'Voice_mail_plan':
# ['No' 'Yes']
# --------------------------------------------------

# %% [markdown]
# ## modeling

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder , RobustScaler , StandardScaler , OrdinalEncoder
from category_encoders.binary import BinaryEncoder
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, KFold, cross_validate
from sklearn.metrics import make_scorer, recall_score, accuracy_score
from sklearn.model_selection import cross_validate, StratifiedKFold

# %% [markdown]
# ## Using cross validation with pipline in modeling

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['International_plan', 'Voice_mail_plan'], dtype='object')

# %%
df.describe()
# Out:
#        Total_day_minutes  Total_day_charge  Total_eve_minutes  \
# count        3333.000000       3333.000000        3333.000000
# mean          179.775098         30.562307         200.980348
# std            54.467389          9.259435          50.713844
# min             0.000000          0.000000           0.000000
# 25%           143.700000         24.430000         166.600000
# 50%           179.400000         30.500000         201.400000
# 75%           216.400000         36.790000         235.300000
# max           350.800000         59.640000         363.700000
#
#        Total_eve_charge  Total_night_minutes  Total_night_charge  \
# count       3333.000000          3333.000000         3333.000000
# mean          17.083540           200.872037            9.039325
# std            4.310668            50.573847            2.275873
# min            0.000000            23.200000            1.040000
# 25%           14.160000           167.000000            7.520000
# ...

# %%
cat_columns = [ "Voice_mail_plan", "International_plan" ] 

num_columns = [ 'Total_day_minutes', "Total_eve_minutes", "Total_day_charge", "Total_eve_charge", "Total_night_minutes", "total_charge"  ]

# %% [markdown]
# ##  for testing pipline work or not

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(sparse_output=False, drop='first'), cat_columns),
        ('num', RobustScaler(), num_columns)
    ],
    remainder='passthrough'  
)

# %%
steps = [
   ('preprocessing', preprocessor),
    ("LR", LogisticRegression())
]

pipeline = Pipeline(steps= steps)

# %%
x = df.drop("Churn", axis = 1 )
y = df["Churn"]

# %%
skf = StratifiedKFold( n_splits=5, shuffle=True, random_state=42 ) 
result = cross_validate(pipeline, x, y, cv= skf, scoring= "accuracy", return_train_score= True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(result["train_score"].mean())
print(result["test_score"].mean())
# Out:
# 0.8640863815503932
# 0.8646888267577924

# %% [markdown]
# ###  **Ok it's pipline is work , lets do it in all models and take the best one**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB , MultinomialNB
# from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### **Trying all models using cross validation and choose the best one for accuracy and recall**

# %%
models = [
      ("LR", LogisticRegression()),
      ("DT", DecisionTreeClassifier()),
      ("RF", RandomForestClassifier()),
      ("SVM", SVC()), 
    # ("GNB", GaussianNB())
    # ("XGB", XGBClassifier())  
]

# %%
y.value_counts()
# Out:
# Churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %%
from sklearn.metrics import make_scorer, recall_score, accuracy_score, precision_score, f1_score
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

scoring = {
    'recall': make_scorer(recall_score),
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score),
    'f1': make_scorer(f1_score)
}

# Loop to apply on all models
for model in models:
    steps = [
   ('preprocessing', preprocessor),
#    ('resampling', SMOTETomek(random_state=42)),
   ("SmoteTomek", SMOTETomek(smote=SMOTE(sampling_strategy={1: 2170}, random_state=24))),
    (model)    
    ]

    pipeline = Pipeline(steps=steps)  # Apply pipeline steps
    
    # Cross-validation
    skf = KFold(n_splits=5, shuffle=True, random_state=42) 
    result = cross_validate(pipeline, x, y, cv=skf, scoring=scoring, return_train_score=True)
    
    # Average recall
    print(f"{model[0]} Average Train Recall: {result['train_recall'].mean():.4f}")
    print(f"{model[0]} Average Test Recall: {result['test_recall'].mean():.4f}")
    
    # Average accuracy
    print(f"{model[0]} Average Train Accuracy: {result['train_accuracy'].mean():.4f}")
    
    print(f"{model[0]} Average Test Accuracy: {result['test_accuracy'].mean():.4f}")
    
    # Average precision 
    print(f"{model[0]} Average Train Precision: {result['train_precision'].mean():.4f}")
    print(f"{model[0]} Average Test Precision: {result['test_precision'].mean():.4f}\n")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ### **chosing Rondom Forest as best model, there are some overfitting will handeled in tuning ,then saved model used in deployment by streamlit**

# %%
steps = [
     ('preprocessing', preprocessor),
     ('resampling', SMOTETomek(random_state=42)),
     ("RF" ,  RandomForestClassifier())
]

pipeline = Pipeline(steps= steps)

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## tuning

# %%
param_grid= { 
                'RF__max_depth': [5, 10, 15, 20 ],  
                'RF__min_samples_split': [2, 5, 10, 15],  
                'RF__min_samples_leaf': [1, 2, 3, 4]                
}

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer, recall_score, accuracy_score

scorers = {
    'recall'  : make_scorer(recall_score),
    'accuracy': make_scorer(accuracy_score)
}

kf = KFold(n_splits=5, shuffle=True, random_state=40)
grid = GridSearchCV( estimator= pipeline, param_grid= param_grid, cv= kf, scoring= scorers, refit='recall',  return_train_score= True )

result = grid.fit(x, y)

# %% [markdown]
# ### **Mean acc and recall**

# %%
result.best_params_
# Out:
# {'RF__max_depth': 10, 'RF__min_samples_leaf': 1, 'RF__min_samples_split': 15}

# %%
result.cv_results_["mean_train_accuracy"][result.best_index_]
# Out:
# np.float64(0.9780978427959071)

# %%
result.cv_results_["mean_test_accuracy"][result.best_index_]
# Out:
# np.float64(0.9681978830404617)

# %%
result.cv_results_["mean_train_recall"][result.best_index_]
# Out:
# np.float64(0.8679954912120055)

# %%
result.cv_results_["mean_test_recall"][result.best_index_]
# Out:
# np.float64(0.845902202143255)

# %%
# final model with best estimators
Final_Model = result.best_estimator_

# %%
# trains the entire pipeline, including all preprocessing steps and model with best parameters 
Final_Model = Final_Model.fit(x, y)

# %%
df
# Out:
#      International_plan Voice_mail_plan  Total_day_minutes  Total_day_charge  \
# 0                    No              No              184.5             31.37
# 1                    No              No              129.1             21.95
# 2                    No              No              332.9             56.59
# 3                    No              No              110.4             18.77
# 4                    No              No              119.3             20.28
# ...                 ...             ...                ...               ...
# 3328                 No              No              134.7             22.90
# 3329                 No             Yes              156.2             26.55
# 3330                 No              No              231.1             39.29
# 3331                 No              No              180.8             30.74
# 3332                 No             Yes              234.4             39.85
#
# ...

# %%
df .describe()
# Out:
#        Total_day_minutes  Total_day_charge  Total_eve_minutes  \
# count        3333.000000       3333.000000        3333.000000
# mean          179.775098         30.562307         200.980348
# std            54.467389          9.259435          50.713844
# min             0.000000          0.000000           0.000000
# 25%           143.700000         24.430000         166.600000
# 50%           179.400000         30.500000         201.400000
# 75%           216.400000         36.790000         235.300000
# max           350.800000         59.640000         363.700000
#
#        Total_eve_charge  Total_night_minutes  Total_night_charge  \
# count       3333.000000          3333.000000         3333.000000
# mean          17.083540           200.872037            9.039325
# std            4.310668            50.573847            2.275873
# min            0.000000            23.200000            1.040000
# 25%           14.160000           167.000000            7.520000
# ...

# %%
df.columns
# Out:
# Index(['International_plan', 'Voice_mail_plan', 'Total_day_minutes',
#        'Total_day_charge', 'Total_eve_minutes', 'Total_eve_charge',
#        'Total_night_minutes', 'Total_night_charge', 'Total_intl_minutes',
#        'Total_intl_calls', 'Total_intl_charge', 'Customer_service_calls',
#        'Churn', 'total_charge', 'tota_minutes'],
#       dtype='object')

# %%
import pickle

# %%
import pickle

file_name = '/Users/mohammedmahmood/Desktop/Data projects/Telecom_churn_prediction.sav'

with open(file_name, "wb") as file:
    pickle.dump(Final_Model, file)
